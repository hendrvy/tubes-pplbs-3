# %% [markdown]
# # Smart Crowd Control - A4 EDA
#
# This notebook documents the Python ML dataset, model metrics, and report generation workflow.

# %%
import pandas as pd
df = pd.read_csv('../data/synthetic_crowd_data.csv')
df.head()

# %%
df[['current_density', 'predicted_density_30m', 'duration_min', 'event_intensity', 'z_score']].describe()

# %%
df['risk_label'].value_counts(normalize=True).rename('share')

# %% [markdown]
# Run `python scripts/generate_report.py` from `python-ml-service/` to regenerate the Markdown report and figures.
